# %% [markdown]
# # Exploratory Data Analysis
# ## Basics of python
# ### Expt-0

# %% [markdown]
# EXP: - Introduction to Python.

# %%
# Vishvam Delwadiya
#PRN: - 25070123124

print("Vishvam Delwadiya")
# Out:
# Vishvam Delwadiya

# %%
print(2)
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
x=2
y=[1,2,5]
z="Vishvam Delwadiya"

print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# Vishvam Delwadiya
