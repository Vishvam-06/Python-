# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishvam-06/Python-/blob/main/Exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exp-2 Study of list in Python

# %%
# Vishvam Delwadiya
#PRN: - 25070123124

# %%
list1=["apple","orange","cherry"]
print(list1)
# Out:
# ['apple', 'orange', 'cherry']

# %%
list2=[2,2.5,"Vishvam",True]
print(list2)
# Out:
# [2, 2.5, 'Vishvam', True]

# %%
list3=["apple","banana","orange","cherry","kiwi","mango"]
print(list3[2])
print(list3[-4])
print(list3[2:5])
print(list3[:5])
print(list3[2:])
print(len(list3))
# Out:
# orange
# orange
# ['orange', 'cherry', 'kiwi']
# ['apple', 'banana', 'orange', 'cherry', 'kiwi']
# ['orange', 'cherry', 'kiwi', 'mango']
# 6

# %%
list4=["apple","orange","cherry"]
list4[1]="mango"
print(list4)
# Out:
# ['apple', 'mango', 'cherry']

# %%
list5=["apple","orange","cherry"]
list5.append("mango")
print(list5)
# Out:
# ['apple', 'orange', 'cherry', 'mango']

# %%
list6=["apple","orange","cherry"]
list6.insert(1,"mango")
print(list6)
# Out:
# ['apple', 'mango', 'orange', 'cherry']

# %%
list7=["apple","banana","orange"]
list8=["kiwi","mango","cherry"]
list7.extend(list8)
print(list7)
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'mango', 'cherry']

# %%
list9=["apple","orange","apple","cherry"]
print(list9)
# Out:
# ['apple', 'orange', 'apple', 'cherry']

# %%
marks = [78,85,90,66,88]
print(max(marks))
print(min(marks))
print(sum(marks))
print(len(marks))
print(sum(marks)/len(marks))
marks.sort()
print(marks)
# Out:
# 90
# 66
# 407
# 5
# 81.4
# [66, 78, 85, 88, 90]

# %%
list=["soda","fruits","vegetables","milk","chocolate"]
list.append("ice cream")
list.remove("soda")
print(list)
# Out:
# ['fruits', 'vegetables', 'milk', 'chocolate', 'ice cream']
