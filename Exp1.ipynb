# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishvam-06/Python-/blob/main/Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exp-1
# Introduction To Python

# %%
# Vishvam Delwadiya
#PRN: - 25070123124

# %%
x,y,z="APPLE","CHERRY","ORANGE"

print(x,y,z,sep="\n")
# Out:
# APPLE
# CHERRY
# ORANGE

# %%
x,y,w,z=2,2.5,"Vishvam",True
print(type(x),type(y),type(w),type(z),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b=10,5
print("sum=",a+b)
print("sub=",a-b)
print("mult=",a*b)
print("div=",a/b)
print("exp=",a**b)
# Out:
# sum= 15
# sub= 5
# mult= 50
# div= 2.0
# exp= 100000

# %%
a,b=10,5
print("sum=",a+b,"\nsub=",a-b,"\nmult=",a*b,"\ndiv=",a/b,"\nexp=",a**b)
# Out:
# sum= 15
# sub= 5
# mult= 50
# div= 2.0
# exp= 100000

# %%
a=int(input("enter the value of a:"))
b=int(input("enter the value of b:"))

print("sum=",a+b, "\nsub=",a-b, "\nmult=",a*b, "\ndiv=",a/b, "\nexp=",a**b)
# Out:
# enter the value of a:3
# enter the value of b:7
# sum= 10
# sub= -4
# mult= 21
# div= 0.42857142857142855
# exp= 2187

# %%
import math
pi=math.pi

r=float(input("enter the radius of circle:"))

print("area of cirlce=",pi*r*r )
# Out:
# enter the radius of circle:5.5
# area of cirlce= 95.03317777109123

# %%
import math
math.log10(10)
# Out:
# 1.0

# %%
a=int(input("enter the value of a:"))
b=int(input("enter the value of b:"))

if(a>b):
    print("a is greater than b")

else:
    print("b is greater than a")
# Out:
# enter the value of a:7
# enter the value of b:9
# b is greater than a
